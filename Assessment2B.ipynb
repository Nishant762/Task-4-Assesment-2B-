# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv(r'/content/college_1.csv') 
print(df1)
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# 1         Computer Science and Engineering       0
# 2         Computer Science and Engineering       0
# 3         Computer Science and Engineering       0
# 4         Computer Science and Engineering       0
# ..                                     ...     ...
# 79  Electronics and Electrical Engineering       0
# 80  Electronics and Electrical Engineering       0
# 81  Electronics and Electrical Engineering       0
# 82  Electronics and Electrical Engineering       0
# 83  Electronics and Electrical Engineering       0
#
# [84 rows x 7 columns]

# %%
df2 = pd.read_csv(r'/content/college_2.csv') 
print(df2)
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# 11    Balaraman Muthupandi      -1          9      0                       0
# 12                JPradhap     100          0      0                       0
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 14               Praneetha      -1         23    100                      -1
# 15             Rahul Raj K      -1          0      0                       0
# 16                 Guhan S      -1         72     35                      39
# 17            Suryarajan S      -1         63     31                       0
# 18          Narasimhan Y L      -1         -1      0                       0
# 19            Leelakrishna      -1          6      4                       0
# 20          PremsagarReddy      -1         20      0                       0
# 21               pradeeban      16         20     24                       0
# 22             santhoshini      -1         43      0                       0
# 23              MUKESH S M      -1         46      0                       0
# 24           P.GOVARDHANAN      -1         40      0                      -1
# 25            SHAIK DANISH      -1         43      0                       0
# 26               sridhar.s      -1         52      0                       0
# 27       Vimalesh Fernando      -1          0      0                       0
# 28           M.Karthikeyan      -1          0      4                       6
# 29               Abishak s      -1         55     35                       6
# 30           praveen raj j      24         -1      0                       0
# 31              AMARNATH D      -1         52     12                      -1
# 32                    bala      32         49      0                      -1
# 33                    XY Z      -1         20     -1                      -1
# 34               Hariharan      -1         -1     -1                       0
#
#     Previous Geekions  CodeKata Score  \
# 0               19400           19400
# 1               14150           14490
# 2                8790           10790
# 3               10040           10040
# 4                9150            9150
# 5                7210            8970
# 6                7250            8950
# 7                8650            8650
# 8                5180            8320
# 9                6170            8160
# 10               7470            8090
# 11               7670            8050
# 12               7340            8030
# 13               6400            7940
# 14               7170            7730
# 15               6280            7640
# 16               7310            7630
# 17               6710            7550
# 18               4800            6800
# 19               5300            6640
# 20               5290            6290
# 21               6060            6090
# 22               3910            5740
# 23               5200            5200
# 24               5050            5050
# 25               4050            4820
# 26               3860            4440
# 27               4170            4170
# 28               4020            4020
# 29               3220            3220
# 30               2380            2380
# 31               1890            1890
# 32               1720            1720
# 33                  0               0
# 34                  0               0
#
#                                    Department  Rising
# 0      Electronics and Electrical Engineering       0
# 1            Computer Science and Engineering     340
# 2            Computer Science and Engineering    2000
# 3   Electronics and Communication Engineering       0
# 4      Electronics and Electrical Engineering       0
# 5            Computer Science and Engineering    1760
# 6            Computer Science and Engineering    1700
# 7   Electronics and Communication Engineering       0
# 8      Electronics and Electrical Engineering    3140
# 9      Electronics and Electrical Engineering    1990
# 10           Computer Science and Engineering     620
# 11           Computer Science and Engineering     380
# 12     Electronics and Electrical Engineering     690
# 13           Computer Science and Engineering    1540
# 14  Electronics and Communication Engineering     560
# 15           Computer Science and Engineering    1360
# 16  Electronics and Communication Engineering     320
# 17           Computer Science and Engineering     840
# 18           Computer Science and Engineering    2000
# 19           Computer Science and Engineering    1340
# 20           Computer Science and Engineering    1000
# 21           Computer Science and Engineering      30
# 22           Computer Science and Engineering    1830
# 23           Computer Science and Engineering       0
# 24  Electronics and Communication Engineering       0
# 25           Computer Science and Engineering     770
# 26           Computer Science and Engineering     580
# 27           Computer Science and Engineering       0
# 28           Computer Science and Engineering       0
# 29  Electronics and Communication Engineering       0
# 30           Computer Science and Engineering       0
# 31  Electronics and Communication Engineering       0
# 32  Electronics and Communication Engineering       0
# 33           Computer Science and Engineering       0
# 34           Computer Science and Engineering       0

# %%
csv_file_list = ["/content/college_1.csv", "/content/college_2.csv"]

list_of_dataframes = []
for filename in csv_file_list:
    list_of_dataframes.append(pd.read_csv(filename))

merged_df = pd.concat(list_of_dataframes)

print(merged_df)
merged_df.to_csv('file1.csv')
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# 1            Computer Science and Engineering       0        NaN
# 2            Computer Science and Engineering       0        NaN
# 3            Computer Science and Engineering       0        NaN
# 4            Computer Science and Engineering       0        NaN
# ..                                        ...     ...        ...
# 30           Computer Science and Engineering       0       -1.0
# 31  Electronics and Communication Engineering       0       52.0
# 32  Electronics and Communication Engineering       0       49.0
# 33           Computer Science and Engineering       0       20.0
# 34           Computer Science and Engineering       0       -1.0
#
#     computational_thinking
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...
# 30                     0.0
# 31                    -1.0
# 32                    -1.0
# 33                    -1.0
# 34                     0.0
#
# [119 rows x 9 columns]

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Exceeded = pd.read_csv(r"/content/file1.csv")
Exceeded_expectations = Exceeded[Exceeded['CodeKata Score']>15000]
Exceeded_expectations.to_csv('Exceeded expectations.csv')

# %%
Reached = pd.read_csv(r"/content/file1.csv")
Reached_expectations = Reached[(Reached['CodeKata Score']>10000)& (Reached['CodeKata Score']<15000)]
Reached_expectations.to_csv("Reached_expectations.csv")

# %%
Needs = pd.read_csv(r"/content/file1.csv")
Needs_Improvement = Needs[(Needs['CodeKata Score']>7000)& (Needs['CodeKata Score']<10000)]
pd.set_option('display.max_rows', Needs.shape[0]+1)
Needs_Improvement.to_csv("Needs_Improvement.csv")

# %%
Unsatis = pd.read_csv(r"/content/file1.csv")
Unsatisfactory = Unsatis[Unsatis['CodeKata Score']<7000]
Unsatisfactory.to_csv("Unsatisfactory.csv")
Unsatisfactory
# Out:
#      Unnamed: 0                        Name  python   mysql  \
# 8             8                  J.SUGANTHI    27.0   50.00
# 9             9                thamizhpaana    29.0    0.00
# 10           10             Iyappan Samiraj    50.0   24.00
# 11           11                Ponniyamma.R   100.0   11.25
# 12           12                   SABAPATHI   100.0    0.00
# 13           13                    RAGHAVAN   100.0    0.00
# 14           14             Melvin Dukles.R    56.0   20.00
# 15           15                    Pavithra   100.0  100.00
# 16           16                 PRIYANKA .S    85.0    4.00
# 17           17                 v.vithyasri   100.0   12.00
# 18           18          Abirami Anbazhagan   100.0    0.00
# 19           19                S.srinivasan   100.0   12.00
# 20           20                    s.janani   100.0    0.00
# 21           21                kamalishwari    32.0   20.00
# 22           22                     Yuvasri   100.0  100.00
# 23           23                      balaji    82.0    0.00
# 24           24                     MEERA.M   100.0  100.00
# 25           25                   Tpavithra   100.0   24.00
# 26           26               sri dharshini   100.0  100.00
# 27           27                    shankari    87.5   20.00
# 28           28               pooja priya.B   100.0  100.00
# 29           29                     chithra   100.0    0.00
# 30           30                  manikandan   100.0    0.00
# 31           31              Kaliaperumal G   100.0    0.00
# 32           32                  SarumathiR    16.0   35.00
# 33           33                   SOWMIYA.V    85.0    0.00
# 34           34                  tamilarasi   100.0  100.00
# 35           35                    Barath D    74.0    4.00
# 36           36                  selvakumar   100.0    0.00
# 37           37                   nivedha.s   100.0   77.00
# 38           38                     Stephen   100.0    0.00
# 39           39                     vignesh    85.0    0.00
# 40           40                  HSharukhan   100.0    0.00
# 41           41                 vijayakumar   100.0    0.00
# 42           42                   ABIRAMI.S    82.0    0.00
# 43           43                  v.gowsalya    53.0   50.00
# 44           44                     ponni.p    93.0  100.00
# 45           45                  PRAVEENA K   100.0  100.00
# 46           46  siva sai perumal polisetti   100.0   12.00
# 47           47                 MadhumathiB    16.0   35.00
# 48           48                   b.akshaya    82.0    0.00
# 49           49                    bavithra     0.0  100.00
# 50           50                   Deivani.S     0.0   86.25
# 51           51                   Nivetha.S     0.0   50.00
# 52           52                 GUNAMATHI.S     0.0   77.00
# 53           53                   RANJITH.R   100.0    0.00
# 54           54                    u.abarna     3.0   39.00
# 55           55                kaviyarasi.k    16.0   28.75
# 56           56                     pravina   100.0  100.00
# 57           57                     M.PRIYA    43.0   24.00
# 58           58                M.Nisha@mary    11.0   20.00
# 59           59                    Thivviya    82.0    8.00
# 60           60                muvendiran.m   100.0    7.50
# 61           61                     Aravind   100.0    0.00
# 62           62                     Haasini   100.0    0.00
# 63           63                    E.Nalini     3.0    0.00
# 64           64                  k.parvathi   100.0  100.00
# 65           65                  jayapratha    82.0    0.00
# 66           66              Evanasundari.K    61.0    0.00
# 67           67                    gousalya    56.0   27.00
# 68           68                 sivaranjini     0.0    3.75
# 69           69                  karthika.G   100.0    0.00
# 70           70                   vignesh B    82.0   20.00
# 71           71                 m.keerthana    97.5    0.00
# 72           72                  Subhashini   100.0    4.00
# 73           73              rajesh kumar.r    30.0    0.00
# 74           74             J.Bhuvaneshwari   100.0   20.00
# 75           75                    santhosh    82.0   12.00
# 76           76                        Arun    95.0    4.00
# 77           77                  J.JAYANTHI   100.0  100.00
# 78           78                vikneshwaran   100.0    4.00
# 79           79                KarthikeyanS    45.0    0.00
# 80           80                    BARATH.P    29.0    0.00
# 81           81               N.Ajith kumar    82.0    0.00
# 82           82                mohamed nabi     0.0    0.00
# 83           83              yaser ahamed.A     0.0   27.00
# 102          18              Narasimhan Y L    -1.0    0.00
# 103          19                Leelakrishna    -1.0    4.00
# 104          20              PremsagarReddy    -1.0    0.00
# 105          21                   pradeeban    16.0   24.00
# 106          22                 santhoshini    -1.0    0.00
# 107          23                  MUKESH S M    -1.0    0.00
# 108          24               P.GOVARDHANAN    -1.0    0.00
# 109          25                SHAIK DANISH    -1.0    0.00
# 110          26                   sridhar.s    -1.0    0.00
# 111          27           Vimalesh Fernando    -1.0    0.00
# 112          28               M.Karthikeyan    -1.0    4.00
# 113          29                   Abishak s    -1.0   35.00
# 114          30               praveen raj j    24.0    0.00
# 115          31                  AMARNATH D    -1.0   12.00
# 116          32                        bala    32.0    0.00
# 117          33                        XY Z    -1.0   -1.00
# 118          34                   Hariharan    -1.0   -1.00
#
#      Previous Geekions  CodeKata Score  \
# 8                 5860            5860
# 9                 5500            5500
# 10                5400            5400
# 11                5380            5380
# 12                5280            5280
# 13                5120            5120
# 14                4800            4800
# 15                4600            4600
# 16                4510            4510
# 17                4370            4370
# 18                4320            4320
# 19                4090            4090
# 20                3915            3915
# 21                3665            3665
# 22                3460            3460
# 23                3280            3280
# 24                3200            3200
# 25                3200            3200
# 26                3110            3110
# 27                3000            3000
# 28                2570            2570
# 29                2410            2410
# 30                2360            2360
# 31                2260            2260
# 32                2240            2240
# 33                2160            2160
# 34                1910            1910
# 35                1910            1910
# 36                1900            1900
# 37                1880            1880
# 38                1880            1880
# 39                1740            1740
# 40                1680            1680
# 41                1580            1580
# 42                1580            1580
# 43                1440            1440
# 44                1350            1350
# 45                1320            1320
# 46                1240            1240
# 47                1130            1130
# 48                1100            1100
# 49                1020            1020
# 50                 980             980
# 51                 950             950
# 52                 850             850
# 53                 800             800
# 54                 770             770
# 55                 760             760
# 56                 720             720
# 57                 690             690
# 58                 580             580
# 59                 490             490
# 60                 410             410
# 61                 380             380
# 62                 300             300
# 63                 270             270
# 64                 260             260
# 65                 200             200
# 66                 180             180
# 67                 170             170
# 68                 160             160
# 69                 120             120
# 70                 120             120
# 71                 120             120
# 72                 120             120
# 73                 100             100
# 74                 100             100
# 75                  60              60
# 76                  40              40
# 77                  40              40
# 78                  40              40
# 79                   0               0
# 80                   0               0
# 81                   0               0
# 82                   0               0
# 83                   0               0
# 102               4800            6800
# 103               5300            6640
# 104               5290            6290
# 105               6060            6090
# 106               3910            5740
# 107               5200            5200
# 108               5050            5050
# 109               4050            4820
# 110               3860            4440
# 111               4170            4170
# 112               4020            4020
# 113               3220            3220
# 114               2380            2380
# 115               1890            1890
# 116               1720            1720
# 117                  0               0
# 118                  0               0
#
#                                     Department  Rising  python_en  \
# 8    Electronics and Communication Engineering       0        NaN
# 9             Computer Science and Engineering       0        NaN
# 10   Electronics and Communication Engineering       0        NaN
# 11            Computer Science and Engineering       0        NaN
# 12            Computer Science and Engineering       0        NaN
# 13            Computer Science and Engineering       0        NaN
# 14   Electronics and Communication Engineering       0        NaN
# 15            Computer Science and Engineering       0        NaN
# 16            Computer Science and Engineering       0        NaN
# 17   Electronics and Communication Engineering       0        NaN
# 18   Electronics and Communication Engineering       0        NaN
# 19            Computer Science and Engineering       0        NaN
# 20            Computer Science and Engineering       0        NaN
# 21   Electronics and Communication Engineering       0        NaN
# 22            Computer Science and Engineering       0        NaN
# 23            Computer Science and Engineering       0        NaN
# 24            Computer Science and Engineering       0        NaN
# 25   Electronics and Communication Engineering       0        NaN
# 26            Computer Science and Engineering       0        NaN
# 27   Electronics and Communication Engineering       0        NaN
# 28            Computer Science and Engineering       0        NaN
# 29            Computer Science and Engineering       0        NaN
# 30            Computer Science and Engineering       0        NaN
# 31            Computer Science and Engineering       0        NaN
# 32   Electronics and Communication Engineering       0        NaN
# 33            Computer Science and Engineering       0        NaN
# 34            Computer Science and Engineering       0        NaN
# 35   Electronics and Communication Engineering       0        NaN
# 36            Computer Science and Engineering       0        NaN
# 37            Computer Science and Engineering       0        NaN
# 38            Computer Science and Engineering       0        NaN
# 39   Electronics and Communication Engineering       0        NaN
# 40            Computer Science and Engineering       0        NaN
# 41            Computer Science and Engineering       0        NaN
# 42   Electronics and Communication Engineering       0        NaN
# 43   Electronics and Communication Engineering       0        NaN
# 44            Computer Science and Engineering       0        NaN
# 45            Computer Science and Engineering       0        NaN
# 46   Electronics and Communication Engineering       0        NaN
# 47   Electronics and Communication Engineering       0        NaN
# 48            Computer Science and Engineering       0        NaN
# 49   Electronics and Communication Engineering       0        NaN
# 50   Electronics and Communication Engineering       0        NaN
# 51   Electronics and Communication Engineering       0        NaN
# 52   Electronics and Communication Engineering       0        NaN
# 53   Electronics and Communication Engineering       0        NaN
# 54   Electronics and Communication Engineering       0        NaN
# 55   Electronics and Communication Engineering       0        NaN
# 56            Computer Science and Engineering       0        NaN
# 57   Electronics and Communication Engineering       0        NaN
# 58   Electronics and Communication Engineering       0        NaN
# 59            Computer Science and Engineering       0        NaN
# 60   Electronics and Communication Engineering       0        NaN
# 61            Computer Science and Engineering       0        NaN
# 62            Computer Science and Engineering       0        NaN
# 63   Electronics and Communication Engineering       0        NaN
# 64      Electronics and Electrical Engineering       0        NaN
# 65            Computer Science and Engineering       0        NaN
# 66            Computer Science and Engineering       0        NaN
# 67   Electronics and Communication Engineering       0        NaN
# 68   Electronics and Communication Engineering       0        NaN
# 69            Computer Science and Engineering       0        NaN
# 70   Electronics and Communication Engineering       0        NaN
# 71      Electronics and Electrical Engineering       0        NaN
# 72      Electronics and Electrical Engineering       0        NaN
# 73   Electronics and Communication Engineering       0        NaN
# 74      Electronics and Electrical Engineering       0        NaN
# 75      Electronics and Electrical Engineering       0        NaN
# 76            Computer Science and Engineering       0        NaN
# 77      Electronics and Electrical Engineering       0        NaN
# 78      Electronics and Electrical Engineering       0        NaN
# 79      Electronics and Electrical Engineering       0        NaN
# 80      Electronics and Electrical Engineering       0        NaN
# 81      Electronics and Electrical Engineering       0        NaN
# 82      Electronics and Electrical Engineering       0        NaN
# 83      Electronics and Electrical Engineering       0        NaN
# 102           Computer Science and Engineering    2000       -1.0
# 103           Computer Science and Engineering    1340        6.0
# 104           Computer Science and Engineering    1000       20.0
# 105           Computer Science and Engineering      30       20.0
# 106           Computer Science and Engineering    1830       43.0
# 107           Computer Science and Engineering       0       46.0
# 108  Electronics and Communication Engineering       0       40.0
# 109           Computer Science and Engineering     770       43.0
# 110           Computer Science and Engineering     580       52.0
# 111           Computer Science and Engineering       0        0.0
# 112           Computer Science and Engineering       0        0.0
# 113  Electronics and Communication Engineering       0       55.0
# 114           Computer Science and Engineering       0       -1.0
# 115  Electronics and Communication Engineering       0       52.0
# 116  Electronics and Communication Engineering       0       49.0
# 117           Computer Science and Engineering       0       20.0
# 118           Computer Science and Engineering       0       -1.0
#
#      computational_thinking
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36                      NaN
# 37                      NaN
# 38                      NaN
# 39                      NaN
# 40                      NaN
# 41                      NaN
# 42                      NaN
# 43                      NaN
# 44                      NaN
# 45                      NaN
# 46                      NaN
# 47                      NaN
# 48                      NaN
# 49                      NaN
# 50                      NaN
# 51                      NaN
# 52                      NaN
# 53                      NaN
# 54                      NaN
# 55                      NaN
# 56                      NaN
# 57                      NaN
# 58                      NaN
# 59                      NaN
# 60                      NaN
# 61                      NaN
# 62                      NaN
# 63                      NaN
# 64                      NaN
# 65                      NaN
# 66                      NaN
# 67                      NaN
# 68                      NaN
# 69                      NaN
# 70                      NaN
# 71                      NaN
# 72                      NaN
# 73                      NaN
# 74                      NaN
# 75                      NaN
# 76                      NaN
# 77                      NaN
# 78                      NaN
# 79                      NaN
# 80                      NaN
# 81                      NaN
# 82                      NaN
# 83                      NaN
# 102                     0.0
# 103                     0.0
# 104                     0.0
# 105                     0.0
# 106                     0.0
# 107                     0.0
# 108                    -1.0
# 109                     0.0
# 110                     0.0
# 111                     0.0
# 112                     6.0
# 113                     6.0
# 114                     0.0
# 115                    -1.0
# 116                    -1.0
# 117                    -1.0
# 118                     0.0

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df = pd.read_csv(r"/content/file1.csv")
pd.set_option('display.max_rows',df.shape[0]+1)
print(df['Previous Geekions'].mean())

#Average of Codekata score
df = pd.read_csv(r"/content/file1.csv")
print(df['CodeKata Score'].mean())
# Out:
# 3842.3529411764707
# 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
dataframe = pd.read_csv(r"/content/file1.csv")
print(dataframe['Name'].count())
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
Highest = pd.read_csv('/content/file1.csv')
Highest
# Out:
#      Unnamed: 0                        Name  python   mysql  \
# 0             0                   A.Dharani    82.0   20.00
# 1             1                 V.JEEVITHA     82.0   20.00
# 2             2                 HEMAVATHI.R   100.0  100.00
# 3             3                 Mugunthan S   100.0   47.00
# 4             4                 Sathammai.S   100.0    8.00
# 5             5                NIVEESHWAR S   100.0    0.00
# 6             6               KALAIARASAN K    85.0   47.00
# 7             7        MOHAMED ZUBAIR AHMED    82.0    4.00
# 8             8                  J.SUGANTHI    27.0   50.00
# 9             9                thamizhpaana    29.0    0.00
# 10           10             Iyappan Samiraj    50.0   24.00
# 11           11                Ponniyamma.R   100.0   11.25
# 12           12                   SABAPATHI   100.0    0.00
# 13           13                    RAGHAVAN   100.0    0.00
# 14           14             Melvin Dukles.R    56.0   20.00
# 15           15                    Pavithra   100.0  100.00
# 16           16                 PRIYANKA .S    85.0    4.00
# 17           17                 v.vithyasri   100.0   12.00
# 18           18          Abirami Anbazhagan   100.0    0.00
# 19           19                S.srinivasan   100.0   12.00
# 20           20                    s.janani   100.0    0.00
# 21           21                kamalishwari    32.0   20.00
# 22           22                     Yuvasri   100.0  100.00
# 23           23                      balaji    82.0    0.00
# 24           24                     MEERA.M   100.0  100.00
# 25           25                   Tpavithra   100.0   24.00
# 26           26               sri dharshini   100.0  100.00
# 27           27                    shankari    87.5   20.00
# 28           28               pooja priya.B   100.0  100.00
# 29           29                     chithra   100.0    0.00
# 30           30                  manikandan   100.0    0.00
# 31           31              Kaliaperumal G   100.0    0.00
# 32           32                  SarumathiR    16.0   35.00
# 33           33                   SOWMIYA.V    85.0    0.00
# 34           34                  tamilarasi   100.0  100.00
# 35           35                    Barath D    74.0    4.00
# 36           36                  selvakumar   100.0    0.00
# 37           37                   nivedha.s   100.0   77.00
# 38           38                     Stephen   100.0    0.00
# 39           39                     vignesh    85.0    0.00
# 40           40                  HSharukhan   100.0    0.00
# 41           41                 vijayakumar   100.0    0.00
# 42           42                   ABIRAMI.S    82.0    0.00
# 43           43                  v.gowsalya    53.0   50.00
# 44           44                     ponni.p    93.0  100.00
# 45           45                  PRAVEENA K   100.0  100.00
# 46           46  siva sai perumal polisetti   100.0   12.00
# 47           47                 MadhumathiB    16.0   35.00
# 48           48                   b.akshaya    82.0    0.00
# 49           49                    bavithra     0.0  100.00
# 50           50                   Deivani.S     0.0   86.25
# 51           51                   Nivetha.S     0.0   50.00
# 52           52                 GUNAMATHI.S     0.0   77.00
# 53           53                   RANJITH.R   100.0    0.00
# 54           54                    u.abarna     3.0   39.00
# 55           55                kaviyarasi.k    16.0   28.75
# 56           56                     pravina   100.0  100.00
# 57           57                     M.PRIYA    43.0   24.00
# 58           58                M.Nisha@mary    11.0   20.00
# 59           59                    Thivviya    82.0    8.00
# 60           60                muvendiran.m   100.0    7.50
# 61           61                     Aravind   100.0    0.00
# 62           62                     Haasini   100.0    0.00
# 63           63                    E.Nalini     3.0    0.00
# 64           64                  k.parvathi   100.0  100.00
# 65           65                  jayapratha    82.0    0.00
# 66           66              Evanasundari.K    61.0    0.00
# 67           67                    gousalya    56.0   27.00
# 68           68                 sivaranjini     0.0    3.75
# 69           69                  karthika.G   100.0    0.00
# 70           70                   vignesh B    82.0   20.00
# 71           71                 m.keerthana    97.5    0.00
# 72           72                  Subhashini   100.0    4.00
# 73           73              rajesh kumar.r    30.0    0.00
# 74           74             J.Bhuvaneshwari   100.0   20.00
# 75           75                    santhosh    82.0   12.00
# 76           76                        Arun    95.0    4.00
# 77           77                  J.JAYANTHI   100.0  100.00
# 78           78                vikneshwaran   100.0    4.00
# 79           79                KarthikeyanS    45.0    0.00
# 80           80                    BARATH.P    29.0    0.00
# 81           81               N.Ajith kumar    82.0    0.00
# 82           82                mohamed nabi     0.0    0.00
# 83           83              yaser ahamed.A     0.0   27.00
# 84            0               ASHOK KUMAR K   100.0   31.00
# 85            1                     Chandru     0.0    0.00
# 86            2           Ganesh Ramkumar R    -1.0   24.00
# 87            3             Bodipudi Harini    -1.0   35.00
# 88            4                   VIINU V P    -1.0   24.00
# 89            5                  Poojitha Y     0.0   35.00
# 90            6      Gowtham Chandrasekaran    -1.0    0.00
# 91            7                   Gowtham R    -1.0    4.00
# 92            8                    shifak N    58.0    0.00
# 93            9                     Balaji     -1.0   20.00
# 94           10                    Rushitha    -1.0   62.00
# 95           11        Balaraman Muthupandi    -1.0    0.00
# 96           12                    JPradhap   100.0    0.00
# 97           13               SRIRAMKUMAR B    -1.0    0.00
# 98           14                   Praneetha    -1.0  100.00
# 99           15                 Rahul Raj K    -1.0    0.00
# 100          16                     Guhan S    -1.0   35.00
# 101          17                Suryarajan S    -1.0   31.00
# 102          18              Narasimhan Y L    -1.0    0.00
# 103          19                Leelakrishna    -1.0    4.00
# 104          20              PremsagarReddy    -1.0    0.00
# 105          21                   pradeeban    16.0   24.00
# 106          22                 santhoshini    -1.0    0.00
# 107          23                  MUKESH S M    -1.0    0.00
# 108          24               P.GOVARDHANAN    -1.0    0.00
# 109          25                SHAIK DANISH    -1.0    0.00
# 110          26                   sridhar.s    -1.0    0.00
# 111          27           Vimalesh Fernando    -1.0    0.00
# 112          28               M.Karthikeyan    -1.0    4.00
# 113          29                   Abishak s    -1.0   35.00
# 114          30               praveen raj j    24.0    0.00
# 115          31                  AMARNATH D    -1.0   12.00
# 116          32                        bala    32.0    0.00
# 117          33                        XY Z    -1.0   -1.00
# 118          34                   Hariharan    -1.0   -1.00
#
#      Previous Geekions  CodeKata Score  \
# 0                24500           24500
# 1                21740           21740
# 2                19680           19680
# 3                10610           10610
# 4                 8980            8980
# 5                 8200            8200
# 6                 7750            7880
# 7                 7020            7020
# 8                 5860            5860
# 9                 5500            5500
# 10                5400            5400
# 11                5380            5380
# 12                5280            5280
# 13                5120            5120
# 14                4800            4800
# 15                4600            4600
# 16                4510            4510
# 17                4370            4370
# 18                4320            4320
# 19                4090            4090
# 20                3915            3915
# 21                3665            3665
# 22                3460            3460
# 23                3280            3280
# 24                3200            3200
# 25                3200            3200
# 26                3110            3110
# 27                3000            3000
# 28                2570            2570
# 29                2410            2410
# 30                2360            2360
# 31                2260            2260
# 32                2240            2240
# 33                2160            2160
# 34                1910            1910
# 35                1910            1910
# 36                1900            1900
# 37                1880            1880
# 38                1880            1880
# 39                1740            1740
# 40                1680            1680
# 41                1580            1580
# 42                1580            1580
# 43                1440            1440
# 44                1350            1350
# 45                1320            1320
# 46                1240            1240
# 47                1130            1130
# 48                1100            1100
# 49                1020            1020
# 50                 980             980
# 51                 950             950
# 52                 850             850
# 53                 800             800
# 54                 770             770
# 55                 760             760
# 56                 720             720
# 57                 690             690
# 58                 580             580
# 59                 490             490
# 60                 410             410
# 61                 380             380
# 62                 300             300
# 63                 270             270
# 64                 260             260
# 65                 200             200
# 66                 180             180
# 67                 170             170
# 68                 160             160
# 69                 120             120
# 70                 120             120
# 71                 120             120
# 72                 120             120
# 73                 100             100
# 74                 100             100
# 75                  60              60
# 76                  40              40
# 77                  40              40
# 78                  40              40
# 79                   0               0
# 80                   0               0
# 81                   0               0
# 82                   0               0
# 83                   0               0
# 84               19400           19400
# 85               14150           14490
# 86                8790           10790
# 87               10040           10040
# 88                9150            9150
# 89                7210            8970
# 90                7250            8950
# 91                8650            8650
# 92                5180            8320
# 93                6170            8160
# 94                7470            8090
# 95                7670            8050
# 96                7340            8030
# 97                6400            7940
# 98                7170            7730
# 99                6280            7640
# 100               7310            7630
# 101               6710            7550
# 102               4800            6800
# 103               5300            6640
# 104               5290            6290
# 105               6060            6090
# 106               3910            5740
# 107               5200            5200
# 108               5050            5050
# 109               4050            4820
# 110               3860            4440
# 111               4170            4170
# 112               4020            4020
# 113               3220            3220
# 114               2380            2380
# 115               1890            1890
# 116               1720            1720
# 117                  0               0
# 118                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# 1             Computer Science and Engineering       0        NaN
# 2             Computer Science and Engineering       0        NaN
# 3             Computer Science and Engineering       0        NaN
# 4             Computer Science and Engineering       0        NaN
# 5             Computer Science and Engineering       0        NaN
# 6    Electronics and Communication Engineering     130        NaN
# 7             Computer Science and Engineering       0        NaN
# 8    Electronics and Communication Engineering       0        NaN
# 9             Computer Science and Engineering       0        NaN
# 10   Electronics and Communication Engineering       0        NaN
# 11            Computer Science and Engineering       0        NaN
# 12            Computer Science and Engineering       0        NaN
# 13            Computer Science and Engineering       0        NaN
# 14   Electronics and Communication Engineering       0        NaN
# 15            Computer Science and Engineering       0        NaN
# 16            Computer Science and Engineering       0        NaN
# 17   Electronics and Communication Engineering       0        NaN
# 18   Electronics and Communication Engineering       0        NaN
# 19            Computer Science and Engineering       0        NaN
# 20            Computer Science and Engineering       0        NaN
# 21   Electronics and Communication Engineering       0        NaN
# 22            Computer Science and Engineering       0        NaN
# 23            Computer Science and Engineering       0        NaN
# 24            Computer Science and Engineering       0        NaN
# 25   Electronics and Communication Engineering       0        NaN
# 26            Computer Science and Engineering       0        NaN
# 27   Electronics and Communication Engineering       0        NaN
# 28            Computer Science and Engineering       0        NaN
# 29            Computer Science and Engineering       0        NaN
# 30            Computer Science and Engineering       0        NaN
# 31            Computer Science and Engineering       0        NaN
# 32   Electronics and Communication Engineering       0        NaN
# 33            Computer Science and Engineering       0        NaN
# 34            Computer Science and Engineering       0        NaN
# 35   Electronics and Communication Engineering       0        NaN
# 36            Computer Science and Engineering       0        NaN
# 37            Computer Science and Engineering       0        NaN
# 38            Computer Science and Engineering       0        NaN
# 39   Electronics and Communication Engineering       0        NaN
# 40            Computer Science and Engineering       0        NaN
# 41            Computer Science and Engineering       0        NaN
# 42   Electronics and Communication Engineering       0        NaN
# 43   Electronics and Communication Engineering       0        NaN
# 44            Computer Science and Engineering       0        NaN
# 45            Computer Science and Engineering       0        NaN
# 46   Electronics and Communication Engineering       0        NaN
# 47   Electronics and Communication Engineering       0        NaN
# 48            Computer Science and Engineering       0        NaN
# 49   Electronics and Communication Engineering       0        NaN
# 50   Electronics and Communication Engineering       0        NaN
# 51   Electronics and Communication Engineering       0        NaN
# 52   Electronics and Communication Engineering       0        NaN
# 53   Electronics and Communication Engineering       0        NaN
# 54   Electronics and Communication Engineering       0        NaN
# 55   Electronics and Communication Engineering       0        NaN
# 56            Computer Science and Engineering       0        NaN
# 57   Electronics and Communication Engineering       0        NaN
# 58   Electronics and Communication Engineering       0        NaN
# 59            Computer Science and Engineering       0        NaN
# 60   Electronics and Communication Engineering       0        NaN
# 61            Computer Science and Engineering       0        NaN
# 62            Computer Science and Engineering       0        NaN
# 63   Electronics and Communication Engineering       0        NaN
# 64      Electronics and Electrical Engineering       0        NaN
# 65            Computer Science and Engineering       0        NaN
# 66            Computer Science and Engineering       0        NaN
# 67   Electronics and Communication Engineering       0        NaN
# 68   Electronics and Communication Engineering       0        NaN
# 69            Computer Science and Engineering       0        NaN
# 70   Electronics and Communication Engineering       0        NaN
# 71      Electronics and Electrical Engineering       0        NaN
# 72      Electronics and Electrical Engineering       0        NaN
# 73   Electronics and Communication Engineering       0        NaN
# 74      Electronics and Electrical Engineering       0        NaN
# 75      Electronics and Electrical Engineering       0        NaN
# 76            Computer Science and Engineering       0        NaN
# 77      Electronics and Electrical Engineering       0        NaN
# 78      Electronics and Electrical Engineering       0        NaN
# 79      Electronics and Electrical Engineering       0        NaN
# 80      Electronics and Electrical Engineering       0        NaN
# 81      Electronics and Electrical Engineering       0        NaN
# 82      Electronics and Electrical Engineering       0        NaN
# 83      Electronics and Electrical Engineering       0        NaN
# 84      Electronics and Electrical Engineering       0        0.0
# 85            Computer Science and Engineering     340       20.0
# 86            Computer Science and Engineering    2000       55.0
# 87   Electronics and Communication Engineering       0        0.0
# 88      Electronics and Electrical Engineering       0      100.0
# 89            Computer Science and Engineering    1760       78.0
# 90            Computer Science and Engineering    1700        0.0
# 91   Electronics and Communication Engineering       0       60.0
# 92      Electronics and Electrical Engineering    3140        0.0
# 93      Electronics and Electrical Engineering    1990      100.0
# 94            Computer Science and Engineering     620       15.0
# 95            Computer Science and Engineering     380        9.0
# 96      Electronics and Electrical Engineering     690        0.0
# 97            Computer Science and Engineering    1540        0.0
# 98   Electronics and Communication Engineering     560       23.0
# 99            Computer Science and Engineering    1360        0.0
# 100  Electronics and Communication Engineering     320       72.0
# 101           Computer Science and Engineering     840       63.0
# 102           Computer Science and Engineering    2000       -1.0
# 103           Computer Science and Engineering    1340        6.0
# 104           Computer Science and Engineering    1000       20.0
# 105           Computer Science and Engineering      30       20.0
# 106           Computer Science and Engineering    1830       43.0
# 107           Computer Science and Engineering       0       46.0
# 108  Electronics and Communication Engineering       0       40.0
# 109           Computer Science and Engineering     770       43.0
# 110           Computer Science and Engineering     580       52.0
# 111           Computer Science and Engineering       0        0.0
# 112           Computer Science and Engineering       0        0.0
# 113  Electronics and Communication Engineering       0       55.0
# 114           Computer Science and Engineering       0       -1.0
# 115  Electronics and Communication Engineering       0       52.0
# 116  Electronics and Communication Engineering       0       49.0
# 117           Computer Science and Engineering       0       20.0
# 118           Computer Science and Engineering       0       -1.0
#
#      computational_thinking
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27                      NaN
# 28                      NaN
# 29                      NaN
# 30                      NaN
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34                      NaN
# 35                      NaN
# 36                      NaN
# 37                      NaN
# 38                      NaN
# 39                      NaN
# 40                      NaN
# 41                      NaN
# 42                      NaN
# 43                      NaN
# 44                      NaN
# 45                      NaN
# 46                      NaN
# 47                      NaN
# 48                      NaN
# 49                      NaN
# 50                      NaN
# 51                      NaN
# 52                      NaN
# 53                      NaN
# 54                      NaN
# 55                      NaN
# 56                      NaN
# 57                      NaN
# 58                      NaN
# 59                      NaN
# 60                      NaN
# 61                      NaN
# 62                      NaN
# 63                      NaN
# 64                      NaN
# 65                      NaN
# 66                      NaN
# 67                      NaN
# 68                      NaN
# 69                      NaN
# 70                      NaN
# 71                      NaN
# 72                      NaN
# 73                      NaN
# 74                      NaN
# 75                      NaN
# 76                      NaN
# 77                      NaN
# 78                      NaN
# 79                      NaN
# 80                      NaN
# 81                      NaN
# 82                      NaN
# 83                      NaN
# 84                      9.0
# 85                      0.0
# 86                      6.0
# 87                     -1.0
# 88                     -1.0
# 89                      0.0
# 90                      3.0
# 91                      6.0
# 92                      0.0
# 93                      0.0
# 94                      9.0
# 95                      0.0
# 96                      0.0
# 97                      0.0
# 98                     -1.0
# 99                      0.0
# 100                    39.0
# 101                     0.0
# 102                     0.0
# 103                     0.0
# 104                     0.0
# 105                     0.0
# 106                     0.0
# 107                     0.0
# 108                    -1.0
# 109                     0.0
# 110                     0.0
# 111                     0.0
# 112                     6.0
# 113                     6.0
# 114                     0.0
# 115                    -1.0
# 116                    -1.0
# 117                    -1.0
# 118                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
Highest = pd.read_csv('/content/file1.csv')

Highest.nlargest(3, ['CodeKata Score'])
# Out:
#    Unnamed: 0         Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           0    A.Dharani    82.0   20.0              24500           24500
# 1           1  V.JEEVITHA     82.0   20.0              21740           21740
# 2           2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
#Calculating the different department total counts
df = pd.read_csv ('/content/file1.csv')
#pd.set_option('display.max_rows',df.shape[0]+1)
item_counts = df["Department"].value_counts()
print(item_counts)
# Out:
# Computer Science and Engineering             63
# Electronics and Communication Engineering    39
# Electronics and Electrical Engineering       17
# Name: Department, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline

df = pd.read_csv ('/content/file1.csv')

data = df.groupby(df["Department"])["CodeKata Score"].sum()
axis('equal');
plt.title('Department wise codekata performance ')
pie(data, labels=data.index,autopct="%.1f%%",explode = (0.1, 0.1, 0.1));
show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df = pd.read_csv (r'/content/file1.csv')
pd.set_option('display.max_rows',df.shape[0]+1)
data = df[(df['Department'] == 'Computer Science and Engineering')]
pd.set_option('display.max_rows',df.shape[0]+1)
data.to_csv("Computer Science and Engineering.csv")

# %%
df = pd.read_csv (r'/content/Computer Science and Engineering.csv')
column = df["CodeKata Score"]
max_value = column.max()
print(max_value)
# Out:
# 24500

# %%
df = pd.read_csv (r'/content/file1.csv')
pd.set_option('display.max_rows',df.shape[0]+1)
data = df[(df['Department'] == 'Electronics and Communication Engineering')]
pd.set_option('display.max_rows',df.shape[0]+1)
data.to_csv("Electronics and Communication Engineering.csv")

# %%
df = pd.read_csv (r'/content/Electronics and Communication Engineering.csv')
column = df["CodeKata Score"]
max_value = column.max()
print(max_value)
# Out:
# 10040

# %%
df = pd.read_csv (r'/content/file1.csv')
data = df[(df['Department'] == 'Electronics and Electrical Engineering')]
pd.set_option('display.max_rows',df.shape[0]+1)
data.to_csv("Electronics and Electrical Engineering.csv")

# %%
df = pd.read_csv (r'/content/Electronics and Electrical Engineering.csv')
pd.set_option('display.max_rows',df.shape[0]+1)
max_index = df["CodeKata Score"].idxmax()
a = df.iloc[[max_index]]
temp1 = a[['Name','CodeKata Score','Department']]
temp1

df = pd.read_csv (r'/content/Electronics and Communication Engineering.csv')
pd.set_option('display.max_rows',df.shape[0]+1)
max_index = df["CodeKata Score"].idxmax()
b = df.iloc[[max_index]]
temp2 = b[['Name','CodeKata Score','Department']]
temp2

df = pd.read_csv (r'/content/Computer Science and Engineering.csv')
pd.set_option('display.max_rows',df.shape[0]+1)
max_index = df["CodeKata Score"].idxmax()
c = df.iloc[[max_index]]
temp3 = c[['Name','CodeKata Score','Department']]
temp3
# Out:
#         Name  CodeKata Score                        Department
# 0  A.Dharani           24500  Computer Science and Engineering

# %%
frames = [temp1, temp2, temp3]

result = pd.concat(frames)
result.set_index([pd.Index([0,1,2]),'Name'])
result.to_csv("Topers.csv")

# %%
import seaborn as sns
import pandas as pd
from matplotlib.pyplot import pie, axis, show
# %matplotlib inline

df = pd.read_csv('/content/Topers.csv')

df.plot.barh(x ='Department', y='CodeKata Score',
             title='Department wise topers', color='blue')
